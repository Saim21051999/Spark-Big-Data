# %%
from pyspark.sql import SparkSession

spark=SparkSession.builder.appName("Missing").getOrCreate()

# %%
# Read the data
df = spark.read.csv(r"C:\Users\user\Desktop\cancer.csv",header=True,inferSchema=True)
df.show()
# Out:
# +--------+---------+-----------+------------+--------------+---------+---------------+----------------+--------------+-------------------+-------------+----------------------+---------+----------+------------+-------+-------------+--------------+------------+-----------------+-----------+--------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+----+
# |      id|diagnosis|radius_mean|texture_mean|perimeter_mean|area_mean|smoothness_mean|compactness_mean|concavity_mean|concave points_mean|symmetry_mean|fractal_dimension_mean|radius_se|texture_se|perimeter_se|area_se|smoothness_se|compactness_se|concavity_se|concave points_se|symmetry_se|fractal_dimension_se|radius_worst|texture_worst|perimeter_worst|area_worst|smoothness_worst|compactness_worst|concavity_worst|concave points_worst|symmetry_worst|fractal_dimension_worst|_c32|
# ...

# %%
df.printSchema()
# Out:
# root
#  |-- id: integer (nullable = true)
#  |-- diagnosis: string (nullable = true)
#  |-- radius_mean: double (nullable = true)
#  |-- texture_mean: double (nullable = true)
#  |-- perimeter_mean: double (nullable = true)
#  |-- area_mean: double (nullable = true)
#  |-- smoothness_mean: double (nullable = true)
#  |-- compactness_mean: double (nullable = true)
#  |-- concavity_mean: double (nullable = true)
#  |-- concave points_mean: double (nullable = true)
#  |-- symmetry_mean: double (nullable = true)
#  |-- fractal_dimension_mean: double (nullable = true)
#  |-- radius_se: double (nullable = true)
#  |-- texture_se: double (nullable = true)
#  |-- perimeter_se: double (nullable = true)
#  |-- area_se: double (nullable = true)
#  |-- smoothness_se: double (nullable = true)
#  |-- compactness_se: double (nullable = true)
#  |-- concavity_se: double (nullable = true)
#  |-- concave points_se: double (nullable = true)
#  |-- symmetry_se: double (nullable = true)
# ...

# %%
df.columns
# Out:
# ['id',
#  'diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  '_c32']

# %%
from pyspark.ml.feature import VectorAssembler
feature_assember = VectorAssembler(inputCols=['radius_mean',
 'texture_mean',
 'perimeter_mean',
 'area_mean',
 'smoothness_mean',
 'compactness_mean',
 'concavity_mean',
 'concave points_mean',
 'symmetry_mean',
 'fractal_dimension_mean',
 'radius_se',
 'texture_se',
 'perimeter_se',
 'area_se',
 'smoothness_se',
 'compactness_se',
 'concavity_se',
 'concave points_se',
 'symmetry_se',
 'fractal_dimension_se',
 'radius_worst',
 'texture_worst',
 'perimeter_worst',
 'area_worst',
 'smoothness_worst',
 'compactness_worst',
 'concavity_worst',
 'concave points_worst',
 'symmetry_worst',
 'fractal_dimension_worst'],outputCol='Independent Features')

# %%
df=df.drop('id')

# %%
output = feature_assember.transform(df)
output.show()
# Out:
# +---------+-----------+------------+--------------+---------+---------------+----------------+--------------+-------------------+-------------+----------------------+---------+----------+------------+-------+-------------+--------------+------------+-----------------+-----------+--------------------+------------+-------------+---------------+----------+----------------+-----------------+---------------+--------------------+--------------+-----------------------+----+--------------------+
# |diagnosis|radius_mean|texture_mean|perimeter_mean|area_mean|smoothness_mean|compactness_mean|concavity_mean|concave points_mean|symmetry_mean|fractal_dimension_mean|radius_se|texture_se|perimeter_se|area_se|smoothness_se|compactness_se|concavity_se|concave points_se|symmetry_se|fractal_dimension_se|radius_worst|texture_worst|perimeter_worst|area_worst|smoothness_worst|compactness_worst|concavity_worst|concave points_worst|symmetry_worst|fractal_dimension_worst|_c32|Independent Features|
# ...

# %%
output.columns
# Out:
# ['diagnosis',
#  'radius_mean',
#  'texture_mean',
#  'perimeter_mean',
#  'area_mean',
#  'smoothness_mean',
#  'compactness_mean',
#  'concavity_mean',
#  'concave points_mean',
#  'symmetry_mean',
#  'fractal_dimension_mean',
#  'radius_se',
#  'texture_se',
#  'perimeter_se',
#  'area_se',
#  'smoothness_se',
#  'compactness_se',
#  'concavity_se',
#  'concave points_se',
#  'symmetry_se',
#  'fractal_dimension_se',
#  'radius_worst',
#  'texture_worst',
#  'perimeter_worst',
#  'area_worst',
#  'smoothness_worst',
#  'compactness_worst',
#  'concavity_worst',
#  'concave points_worst',
#  'symmetry_worst',
#  'fractal_dimension_worst',
#  '_c32',
#  'Independent Features']

# %%
finalized_data= output.select("Independent Features","diagnosis")
finalized_data.show()
# Out:
# +--------------------+---------+
# |Independent Features|diagnosis|
# +--------------------+---------+
# |[17.99,10.38,122....|        M|
# |[20.57,17.77,132....|        M|
# |[19.69,21.25,130....|        M|
# |[11.42,20.38,77.5...|        M|
# |[20.29,14.34,135....|        M|
# |[12.45,15.7,82.57...|        M|
# |[18.25,19.98,119....|        M|
# |[13.71,20.83,90.2...|        M|
# |[13.0,21.82,87.5,...|        M|
# |[12.46,24.04,83.9...|        M|
# |[16.02,23.24,102....|        M|
# |[15.78,17.89,103....|        M|
# |[19.17,24.8,132.4...|        M|
# |[15.85,23.95,103....|        M|
# |[13.73,22.61,93.6...|        M|
# |[14.54,27.54,96.7...|        M|
# |[14.68,20.13,94.7...|        M|
# |[16.13,20.68,108....|        M|
# |[19.81,22.15,130....|        M|
# |[13.54,14.36,87.4...|        B|
# +--------------------+---------+
# only showing top 20 rows

# %%
from pyspark.ml.feature import StringIndexer
indexer= StringIndexer(inputCol="diagnosis", outputCol="label")
indexed = indexer.fit(finalized_data).transform(finalized_data)

# %%
indexed.show()
# Out:
# +--------------------+---------+-----+
# |Independent Features|diagnosis|label|
# +--------------------+---------+-----+
# |[17.99,10.38,122....|        M|  1.0|
# |[20.57,17.77,132....|        M|  1.0|
# |[19.69,21.25,130....|        M|  1.0|
# |[11.42,20.38,77.5...|        M|  1.0|
# |[20.29,14.34,135....|        M|  1.0|
# |[12.45,15.7,82.57...|        M|  1.0|
# |[18.25,19.98,119....|        M|  1.0|
# |[13.71,20.83,90.2...|        M|  1.0|
# |[13.0,21.82,87.5,...|        M|  1.0|
# |[12.46,24.04,83.9...|        M|  1.0|
# |[16.02,23.24,102....|        M|  1.0|
# |[15.78,17.89,103....|        M|  1.0|
# |[19.17,24.8,132.4...|        M|  1.0|
# |[15.85,23.95,103....|        M|  1.0|
# |[13.73,22.61,93.6...|        M|  1.0|
# |[14.54,27.54,96.7...|        M|  1.0|
# |[14.68,20.13,94.7...|        M|  1.0|
# |[16.13,20.68,108....|        M|  1.0|
# |[19.81,22.15,130....|        M|  1.0|
# |[13.54,14.36,87.4...|        B|  0.0|
# +--------------------+---------+-----+
# ...

# %%
final_data=indexed.select('Independent Features','label')

# %%
final_data.show()
# Out:
# +--------------------+-----+
# |Independent Features|label|
# +--------------------+-----+
# |[17.99,10.38,122....|  1.0|
# |[20.57,17.77,132....|  1.0|
# |[19.69,21.25,130....|  1.0|
# |[11.42,20.38,77.5...|  1.0|
# |[20.29,14.34,135....|  1.0|
# |[12.45,15.7,82.57...|  1.0|
# |[18.25,19.98,119....|  1.0|
# |[13.71,20.83,90.2...|  1.0|
# |[13.0,21.82,87.5,...|  1.0|
# |[12.46,24.04,83.9...|  1.0|
# |[16.02,23.24,102....|  1.0|
# |[15.78,17.89,103....|  1.0|
# |[19.17,24.8,132.4...|  1.0|
# |[15.85,23.95,103....|  1.0|
# |[13.73,22.61,93.6...|  1.0|
# |[14.54,27.54,96.7...|  1.0|
# |[14.68,20.13,94.7...|  1.0|
# |[16.13,20.68,108....|  1.0|
# |[19.81,22.15,130....|  1.0|
# |[13.54,14.36,87.4...|  0.0|
# +--------------------+-----+
# only showing top 20 rows

# %%
from pyspark.ml.classification import LogisticRegression


# train test split
train_data,test_data = final_data.randomSplit([0.70,0.30])

# %%
# train the logisticRegression Model
classifier=LogisticRegression(featuresCol="Independent Features", labelCol="label")
classifier=classifier.fit(train_data)

# %%
pred_results=classifier.evaluate(test_data)

# %%
pred_results.predictions.show()
# Out:
# +--------------------+-----+--------------------+--------------------+----------+
# |Independent Features|label|       rawPrediction|         probability|prediction|
# +--------------------+-----+--------------------+--------------------+----------+
# |[6.981,13.43,43.7...|  0.0|[1401.53053998129...|           [1.0,0.0]|       0.0|
# |[7.691,25.44,48.3...|  0.0|[742.499106535374...|           [1.0,0.0]|       0.0|
# |[8.196,16.84,51.7...|  0.0|[1038.05919301209...|           [1.0,0.0]|       0.0|
# |[8.597,18.6,54.09...|  0.0|[1668.98017776464...|           [1.0,0.0]|       0.0|
# |[8.618,11.79,54.3...|  0.0|[809.196642389757...|           [1.0,0.0]|       0.0|
# |[8.671,14.45,54.4...|  0.0|[1320.09593898363...|           [1.0,0.0]|       0.0|
# |[8.726,15.83,55.8...|  0.0|[632.021980984386...|           [1.0,0.0]|       0.0|
# |[8.888,14.64,58.7...|  0.0|[2152.49356932086...|           [1.0,0.0]|       0.0|
# ...

# %%
pred_results.predictions.collect()[0]
# Out:
# Row(Independent Features=DenseVector([6.981, 13.43, 43.79, 143.5, 0.117, 0.0757, 0.0, 0.0, 0.193, 0.0782, 0.2241, 1.508, 1.553, 9.833, 0.0102, 0.0108, 0.0, 0.0, 0.0266, 0.0041, 7.93, 19.54, 50.41, 185.2, 0.1584, 0.1202, 0.0, 0.0, 0.2932, 0.0938]), label=0.0, rawPrediction=DenseVector([1401.5305, -1401.5305]), probability=DenseVector([1.0, 0.0]), prediction=0.0)

# %%
pred_labels=pred_results.predictions.select('label','prediction')

# %%
from pyspark.ml.evaluation import BinaryClassificationEvaluator
evaluator=BinaryClassificationEvaluator(rawPredictionCol='prediction',labelCol='label')

# %%
acc = evaluator.evaluate(pred_labels)

# %%
acc
# Out:
# 0.9361799816345272
